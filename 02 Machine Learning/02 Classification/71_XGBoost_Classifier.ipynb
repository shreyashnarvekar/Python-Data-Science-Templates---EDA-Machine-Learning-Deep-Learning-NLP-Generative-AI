# %% [markdown]
# # **XGBOOST - CLASSIFIER**
# > XGBoost is a powerful and efficient algorithm for both **Classification** and **Regression**
#
# > Offering **high accuracy** and **fast performance**
#
# > Tips : Use **Cross Validation** for **better performance**
#
# ### **General Recommendation:**
#   - `For classification:` Start with **XGBoost** or **LightGBM**.
#   - `For Classification [categorical feature and imbalanced dataset] Without Pre-processing data:` **CatBoost**
#   - `For regression:` **LightGBM** or **XGBoost** is highly recommended.
#
# <br>
#
# ---
#
# <br>
#
# ## 1. What is XGBoost?
# - **XGBoost** (eXtreme Gradient Boosting) is an optimized, distributed gradient boosting library.
# - It is designed for speed, efficiency, and performance.
# - Commonly used for supervised learning tasks like classification and regression.
#
# <br>
#
# ---
#
# <br>
#
# ## 2. Key Features
# - **Boosting Framework**: Sequentially builds models to correct errors of previous ones.
# - **Regularization**: Prevents overfitting using L1 and L2 penalties.
# - **Tree-based Model**: Uses decision trees as base learners.
# - **Parallel Processing**: Supports faster computation using multiple cores.
# - **Cross-Platform Support**: Compatible with Python, R, Java, and other languages.
#
# <br>
#
# ---
#
# <br>
#
# ## 3. Comparison of **[Binary and Multi-Class]** Objectives in XGBoost
#
# <table style="width:100%; border-collapse: collapse; font-family: Arial, sans-serif;">
#   <thead>
#     <tr>
#       <th style="padding: 12px; border: 1px solid #ddd; text-align: center; font-size: 16px;">Objective</th>
#       <th style="padding: 12px; border: 1px solid #ddd; text-align: center; font-size: 16px;">Use Case</th>
#       <th style="padding: 12px; border: 1px solid #ddd; text-align: center; font-size: 16px;">Output</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td style="padding: 12px; border: 1px solid #ddd; text-align: center; font-size: 14px;"><b>binary:logistic</b></td>
#       <td style="padding: 12px; border: 1px solid #ddd; text-align: center; font-size: 14px;">Standard binary classification with probabilities</td>
#       <td style="padding: 12px; border: 1px solid #ddd; text-align: center; font-size: 14px;">Probabilities (0-1)</td>
#     </tr>
#     <tr>
#       <td style="padding: 12px; border: 1px solid #ddd; text-align: center; font-size: 14px;"><b>binary:logitraw</b></td>
#       <td style="padding: 12px; border: 1px solid #ddd; text-align: center; font-size: 14px;">Custom processing of raw scores</td>
#       <td style="padding: 12px; border: 1px solid #ddd; text-align: center; font-size: 14px;">Raw log-odds</td>
#     </tr>
#     <tr>
#       <td style="padding: 12px; border: 1px solid #ddd; text-align: center; font-size: 14px;"><b>binary:hinge</b></td>
#       <td style="padding: 12px; border: 1px solid #ddd; text-align: center; font-size: 14px;">Hard binary predictions directly</td>
#       <td style="padding: 12px; border: 1px solid #ddd; text-align: center; font-size: 14px;">Binary labels (0, 1)</td>
#     </tr>
#     <tr>
#       <td style="padding: 12px; border: 1px solid #ddd; text-align: center; font-size: 14px;"><b>multi:softmax</b></td>
#       <td style="padding: 12px; border: 1px solid #ddd; text-align: center; font-size: 14px;">Multi-class classification (predicted class)</td>
#       <td style="padding: 12px; border: 1px solid #ddd; text-align: center; font-size: 14px;">Class labels (0, 1, 2, etc.)</td>
#     </tr>
#     <tr>
#       <td style="padding: 12px; border: 1px solid #ddd; text-align: center; font-size: 14px;"><b>multi:softprob</b></td>
#       <td style="padding: 12px; border: 1px solid #ddd; text-align: center; font-size: 14px;">Multi-class classification (predicted probabilities)</td>
#       <td style="padding: 12px; border: 1px solid #ddd; text-align: center; font-size: 14px;">Class probabilities</td>
#     </tr>
#   </tbody>
# </table>
#
# <br>
#
# ---
#
# <br>
#
# ## 4. Advantages
# - **Handles Missing Values**: Automatically learns best splits for missing values.
# - **Feature Importance**: Provides insights into feature contribution.
# - **Scalability**: Performs well on large datasets.
# - **Regularization**: Reduces the risk of overfitting.
#
# <br>
#
# ---
#
# <br>
#
# ## ⭐ Things to Keep in Mind
# - Ensure compatible versions of **XGBoost** and **scikit-learn**.
# - **Hyperparameter tuning** is essential for **optimal performance**.
# - Watch out for **overfitting** on small datasets; **use cross-validation**.
#
# <br>
#
# ---

# %%
import pandas as pd
import numpy as np
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
data = datasets.load_breast_cancer()
X = data.data
y = data.target

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.2)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
# import XGBoost
import xgboost as xgb

# %% [markdown]
# ```python
# model = xgb.XGBClassifier(
#     # Model Hyperparameters
#     objective='binary:logistic',    # For binary classification, use logistic regression
#     n_estimators=100,              # Number of boosting rounds (trees)
#     max_depth=6,                   # Maximum depth of each tree
#     learning_rate=0.3,             # Step size at each iteration while moving toward a minimum of the loss function
#     subsample=1.0,                 # Fraction of samples used for each tree to prevent overfitting
#     colsample_bytree=1.0,          # Fraction of features used for each tree to prevent overfitting
#     scale_pos_weight=1,            # Controls the balance of positive and negative weights for imbalanced classes
#
#     # Regularization Parameters
#     reg_alpha=0,                   # L1 regularization term on weights (Lasso)
#     reg_lambda=1,                  # L2 regularization term on weights (Ridge)
#     gamma=0,                       # Minimum loss reduction required to make a further partition (higher = more conservative)
#
#     # Tree Growth Parameters
#     min_child_weight=1,            # Minimum number of samples required in a child node to split further
# )
# ```

# %% [markdown]
# <h3>Comparison of <b>[Binary and Multi-Class]</b> Objectives in XGBoost</h3>
#
# <table style="width:100%; border-collapse: collapse; font-family: Arial, sans-serif;">
#   <thead>
#     <tr>
#       <th style="padding: 12px; border: 1px solid #ddd; text-align: center; font-size: 16px;">Objective</th>
#       <th style="padding: 12px; border: 1px solid #ddd; text-align: center; font-size: 16px;">Use Case</th>
#       <th style="padding: 12px; border: 1px solid #ddd; text-align: center; font-size: 16px;">Output</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td style="padding: 12px; border: 1px solid #ddd; text-align: center; font-size: 14px;"><b>binary:logistic</b></td>
#       <td style="padding: 12px; border: 1px solid #ddd; text-align: center; font-size: 14px;">Standard binary classification with probabilities</td>
#       <td style="padding: 12px; border: 1px solid #ddd; text-align: center; font-size: 14px;">Probabilities (0-1)</td>
#     </tr>
#     <tr>
#       <td style="padding: 12px; border: 1px solid #ddd; text-align: center; font-size: 14px;"><b>binary:logitraw</b></td>
#       <td style="padding: 12px; border: 1px solid #ddd; text-align: center; font-size: 14px;">Custom processing of raw scores</td>
#       <td style="padding: 12px; border: 1px solid #ddd; text-align: center; font-size: 14px;">Raw log-odds</td>
#     </tr>
#     <tr>
#       <td style="padding: 12px; border: 1px solid #ddd; text-align: center; font-size: 14px;"><b>binary:hinge</b></td>
#       <td style="padding: 12px; border: 1px solid #ddd; text-align: center; font-size: 14px;">Hard binary predictions directly</td>
#       <td style="padding: 12px; border: 1px solid #ddd; text-align: center; font-size: 14px;">Binary labels (0, 1)</td>
#     </tr>
#     <tr>
#       <td style="padding: 12px; border: 1px solid #ddd; text-align: center; font-size: 14px;"><b>multi:softmax</b></td>
#       <td style="padding: 12px; border: 1px solid #ddd; text-align: center; font-size: 14px;">Multi-class classification (predicted class)</td>
#       <td style="padding: 12px; border: 1px solid #ddd; text-align: center; font-size: 14px;">Class labels (0, 1, 2, etc.)</td>
#     </tr>
#     <tr>
#       <td style="padding: 12px; border: 1px solid #ddd; text-align: center; font-size: 14px;"><b>multi:softprob</b></td>
#       <td style="padding: 12px; border: 1px solid #ddd; text-align: center; font-size: 14px;">Multi-class classification (predicted probabilities)</td>
#       <td style="padding: 12px; border: 1px solid #ddd; text-align: center; font-size: 14px;">Class probabilities</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Initialize the XGBoost Classifier
# We are using only 1 hyperparameter -> [binary:logistic]

model = xgb.XGBClassifier(objective="binary:logistic")

# %% [markdown]
# > Ignore `__sklearn_tags__` Warning: It's non-critical, but compatibility fixes are ongoing in these libraries.

# %%
# Train the dataset with XGBoost Model
model.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_tags.py:354: FutureWarning: The XGBClassifier or classes from which it inherits use `_get_tags` and `_more_tags`. Please define the `__sklearn_tags__` method, or inherit from `sklearn.base.BaseEstimator` and/or other appropriate mixins such as `sklearn.base.TransformerMixin`, `sklearn.base.ClassifierMixin`, `sklearn.base.RegressorMixin`, and `sklearn.base.OutlierMixin`. From scikit-learn 1.7, not defining `__sklearn_tags__` will raise an error.
#   warnings.warn(
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/IPython/core/formatters.py in __call__(self, obj, include, exclude)
#     968
#     969             if method is not None:
# --> 970                 return method(include=include, exclude=exclude)
#     971             return None
#     972         else:
#
# ...

# %%
# Make predictions
y_pred = model.predict(X_test)

# %%
# Evaluate the model
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

accuracy = accuracy_score(y_test, y_pred)
classification = classification_report(y_test, y_pred)

# %%
print(f"Accuracy: {accuracy:.2f}")
# Out:
# Accuracy: 1.00

# %%
print(classification)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        44
#            1       1.00      1.00      1.00        70
#
#     accuracy                           1.00       114
#    macro avg       1.00      1.00      1.00       114
# weighted avg       1.00      1.00      1.00       114
