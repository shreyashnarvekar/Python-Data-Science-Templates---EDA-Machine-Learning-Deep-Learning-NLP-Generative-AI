# %% [markdown]
# # **Dtale** - Automated EDA Library
# Website : https://pypi.org/project/dtale/
#
#
# > Just assign the dataset and It will generate a link just click on it :)

# %%
# !pip install dtale
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 2.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 642.7/642.7 kB 10.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.7/14.7 MB 55.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 74.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 228.0/228.0 kB 14.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 222.5/222.5 kB 11.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 10.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 49.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.9/45.9 kB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 74.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 82.8 MB/s eta 0:00:00
# ...

# %%
import pandas as pd

import dtale

# For Jupyter Notebook : You don't need to write the below 2 lines of code
import dtale.app as dtale_app
dtale_app.USE_COLAB = True # Use_collab will generate a link to show the report

# %%
# Comment this cell while using your own csv file
import seaborn as sns
df = sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch  ...    who adult_male deck  embark_town  alive  alone
# 0         0       3    male  22.0      1      0  ...    man       True  NaN  Southampton     no  False
# 1         1       1  female  38.0      1      0  ...  woman      False    C    Cherbourg    yes  False
# 2         1       3  female  26.0      0      0  ...  woman      False  NaN  Southampton    yes   True
# 3         1       1  female  35.0      1      0  ...  woman      False    C  Southampton    yes  False
# 4         0       3    male  35.0      0      0  ...    man       True  NaN  Southampton     no   True
#
# [5 rows x 15 columns]

# %%
'''
# For CSV files - Use this method
import pandas as pd
df = pd.read_csv('dataset-path-and-name-here')
df.head()
'''

# %%
dtale.show(df)
# Out:
# https://numhnp0go8d-496ff2e9c6d22116-40000-colab.googleusercontent.com/dtale/main/1
